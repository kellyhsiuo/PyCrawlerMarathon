# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'

'''
Your Code Here
'''
r = requests.get(url)
r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/media/icon-72-69b

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

'''
Your Code Here
'''
response = r.text

print(type(response))
print(response)
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# <class 'str'>
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><meta charSet="utf-8"/><meta name=" ...
# window.dataLayer.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});</script><link rel="preload" as="script" href="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M"/><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M"></script><link rel="preload" href="/_next/static/css/dadeeca15b5600e0756f.css" as="style"/><link rel="stylesheet" href="/_next/static/css/dadeeca15b5600e0756f.css" data-n-g=""/><link rel="preload" href="/_next/static/css/64994a5464e7f7073c4f.css" as="style"/><link rel="stylesheet" href="/_next/static/css/64994a5464e7f7073c4f.css" data-n-p=""/><noscript data-n-css="true"></noscript><link rel="preload" href="/_next/static/chunks/c8f7fe3b0e41be846d5687592cf2018ff6e22687.7a44a07f74a8f93e1d70.js" as="script"/><link rel="preload" href="/_next/static/chunks/80e11efd05c4ccaf15f0d376a46097122b1c669e.41631194339cdb7cb4cf.js" as="script"/><link rel="preload" href="/_next/static/chunks/185.98ea6c8825d779f64821.js" as="script"/><link rel="preload" href="/_next/static/chunks/126.6eeaf79eed97dcc34683.js" as="script"/><link rel="preload" href="/_next/static/chunks/153.eada0432594218a8eaa3.js" as="script"/><link rel="preload" href="/_next/static/chunks/380d42e81165839365c4703ae67985f785a96bdc.9416a4c90343161b987e.js" as="script"/><link rel="preload" href="/_next/static/chunks/142.e6067637fed024c898fe.js" as="script"/><link rel="preload" href="/_next/static/chunks/46.60d28d6094641310dc89.js" as="script"/><link rel="preload" href="/_next/static/chunks/25ab9cf1609d20976391c6ff5814a65a5630e52a.77d5c15d8dfa64a8f20e.js" as="script"/><link rel="preload" href="/_next/static/chunks/18f082cfcb1201f92c925dfd848208caf2b75231.cb618eda4dc56580b406.js" as="script"/><link rel="preload" href="/_next/static/chunks/07ddc8feebba80388bd103699a5e8a2319231b85.37ff2c49c54eed9891c8.js" as="script"/><link rel="preload" href="/_next/static/chunks/128.c38afab1785c629fc8d0.js" as="script"/><link rel="preload" href="/_next/static/chunks/main-45a3d20d495d513f2cb2.js" as="script"/><link rel="preload" href="/_next/static/chunks/webpack-2d63783e44c767c0f7b4.js" as="script"/><link rel="preload" href="/_next/static/chunks/framework.c8a40be0a4bd8b0de1e4.js" as="script"/><link rel="preload" href="/_next/static/chunks/commons.58efa1e6e3086be54387.js" as="script"/><link rel="preload" href="/_next/static/chunks/af940c9434548c12cc7c4878ef443046ac565f64.bf9ff1b5108ceceee779.js" as="script"/><link rel="preload" href="/_next/static/chunks/5a16bf8b082149cf34290a37606666dcf70dc96b.a0850b7e6bbc5e7b56ba.js" as="script"/><link rel="preload" href="/_next/static/chunks/0739e2437b785912e27ffd919456f2c63c704c2e.a541b181cefa0c6140be.js" as="script"/><link rel="preload" href="/_next/static/chunks/3f90e53db2b3420ce9913a1147b75a89b251152f.25d5c941585adb2647dc.js" as="script"/><link rel="preload" href="/_next/static/chunks/074bda294865dd2edb60e1064d2ae271203d3d1b.6f5e6c05379fb6f45034.js" as="script"/><link rel="preload" href="/_next/static/chunks/61cc49119d2b5691d6272e0da4eb6fb517431513.e8fd6060c496301a5cad.js" as="script"/><link rel="preload" href="/_next/static/chunks/af2339f2d4829cb0126ee86819160423ab347ed1.4990ff223b58a54d569e.js" as="script"/><link rel="preload" href="/_next/static/chunks/0c80ce41c15f61748a3c63db6ee86255b82b52f9.4a0edc642462b9173dd3.js" as="script"/><link rel="preload" href="/_next/static/chunks/14852e28a2740a7c54d2d091e36b470df7a22399.be5c561c239c5182cada.js" as="script"/><link rel="preload" href="/_next/static/chunks/0f70e0b77fdcbda3872bda2ac8b6464287dd1707.631421c05703653075b8.js" as="script"/><link rel="preload" href="/_next/static/chunks/896ff3868846743fb9bcdf260cd6a0aacc60829b.2998d5ceb1ed3f39a3e9.js" as="script"/><link rel="preload" href="/_next/static/chunks/25ab9cf1609d20976391c6ff5814a65a5630e52a.77d5c15d8dfa64a8f20e.js" as="script"/><link rel="preload" href="/_next/static/chunks/fd52027c4ffa024220f1f2cf0877e464b7f9b6d4.0f51e94084e8c356570a.js" as="script"/><link rel="preload" href="/_next/static/chunks/18f082cfcb120 ...
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .imJSLl{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="ptn2cr-0"]{content:"imJSLl,"}/*!sc*/
# .fsbFQu{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g3[id="oo2grd-0"]{content:"fsbFQu,"}/*!sc*/
# .kpeJHB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;}/*!sc*/
# data-styled.g5[id="oo2grd-2"]{content:"kpeJHB,"}/*!sc*/
# .kUcAWl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-weight:400;font-size:16px;line-height:22px;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .kUcAWl::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g7[id="oo2grd-4"]{content:"kUcAWl,"}/*!sc*/
# .dWIKEI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .dWIKEI form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g10[id="dj0ioy-0"]{content:"dWIKEI,"}/*!sc*/
# .fxLlMR{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .fxLlMR::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fxLlMR::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g12[id="dj0ioy-2"]{content:"fxLlMR,"}/*!sc*/
# .DpBdT{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g13[id="dj0ioy-3"]{content:"DpBdT,"}/*!sc*/
# .kTOvBu{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g18[id="pkcmwm-0"]{content:"kTOvBu,"}/*!sc*/
# .caQTgB{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .caQTgB:hover{color:rgba(0,0,0,1);}/*!sc*/
# .caQTgB::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .kCSJJy{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .kCSJJy:hover{color:rgba(0,0,0,1);}/*!sc*/
# .kCSJJy::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g19[id="pkcmwm-1"]{content:"caQTgB,kCSJJy,"}/*!sc*/
# .gXOxRC{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g30[id="yj50et-0"]{content:"gXOxRC,"}/*!sc*/
# .bTEUYx{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .hGaOnB{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g31[id="yj50et-1"]{content:"bTEUYx,hGaOnB,"}/*!sc*/
# .jfhwKA{display:block;border-radius:50%;object-fit:cover;}/*!sc*/
# data-styled.g32[id="yj50et-2"]{content:"jfhwKA,"}/*!sc*/
# .fSBNzX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g37[id="euk31c-0"]{content:"fSBNzX,"}/*!sc*/
# .iynvdK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g38[id="euk31c-1"]{content:"iynvdK,"}/*!sc*/
# .kFrzdN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g39[id="euk31c-2"]{content:"kFrzdN,"}/*!sc*/
# .faNPqX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .faNPqX:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g40[id="euk31c-3"]{content:"faNPqX,"}/*!sc*/
# .jeAXKr{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g41[id="euk31c-4"]{content:"jeAXKr,"}/*!sc*/
# .bYrMBg{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .hWGeTk{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g48[id="jjui6k-0"]{content:"bYrMBg,hWGeTk,"}/*!sc*/
# .bUWyLN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .bUWyLN .ptn2cr-0{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g49[id="jjui6k-1"]{content:"bUWyLN,"}/*!sc*/
# .fIIvUe{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g50[id="sc-1ahzbiw-0"]{content:"fIIvUe,"}/*!sc*/
# .gpsyNH{display:block;height:100%;}/*!sc*/
# data-styled.g51[id="sc-139xjgq-0"]{content:"gpsyNH,"}/*!sc*/
# .hoYSgn{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g52[id="dqjqtp-0"]{content:"hoYSgn,"}/*!sc*/
# .fNsDOn{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g69[id="fdq12b-0"]{content:"fNsDOn,"}/*!sc*/
# .gaXQMH .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g71[id="lhzs50-0"]{content:"gaXQMH,"}/*!sc*/
# .ejxNIo{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g72[id="dz5d85-0"]{content:"ejxNIo,"}/*!sc*/
# .QJLIQ{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g73[id="dz5d85-1"]{content:"QJLIQ,"}/*!sc*/
# .ekbLjl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g74[id="dz5d85-2"]{content:"ekbLjl,"}/*!sc*/
# .fuMuMk{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g78[id="e7vhde-0"]{content:"fuMuMk,"}/*!sc*/
# .cPhHIR{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .e7vhde-1,.cPhHIR:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .cPhHIR.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .cPhHIR.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g79[id="e7vhde-1"]{content:"cPhHIR,"}/*!sc*/
# .hCguNu{cursor:pointer;}/*!sc*/
# .hCguNu::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .e7vhde-2::before,.simplebar-mouse-entered .hCguNu::before,.simplebar-dragging .hCguNu::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .e7vhde-2::before,.simplebar-hover .hCguNu::before,.simplebar-mouse-entered .hCguNu::before,.simplebar-dragging .hCguNu::before{opacity:1;}/*!sc*/
# .hCguNu.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g80[id="e7vhde-2"]{content:"hCguNu,"}/*!sc*/
# .slyeh{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g82[id="bxef95-0"]{content:"slyeh,"}/*!sc*/
# .iSUXUZ{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g83[id="bxef95-1"]{content:"iSUXUZ,"}/*!sc*/
# .loGeVD{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g119[id="gthja3-1"]{content:"loGeVD,"}/*!sc*/
# .kbdjsU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .kbdjsU:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g126[id="sc-11gkikh-0"]{content:"kbdjsU,"}/*!sc*/
# .cvGPCw{position:relative;}/*!sc*/
# data-styled.g133[id="rlqnj2-0"]{content:"cvGPCw,"}/*!sc*/
# .jvPhGh{visibility:hidden;pointer-events:none;}/*!sc*/
# data-styled.g134[id="rlqnj2-1"]{content:"jvPhGh,"}/*!sc*/
# .eXNumK{position:absolute;left:0;top:0;right:0;bottom:0;}/*!sc*/
# data-styled.g135[id="rlqnj2-2"]{content:"eXNumK,"}/*!sc*/
# .cuaiVf{position:relative;}/*!sc*/
# data-styled.g184[id="nd4ft2-0"]{content:"cuaiVf,"}/*!sc*/
# .fUhntA{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .fUhntA vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g230[id="sc-1x2g0l4-0"]{content:"fUhntA,"}/*!sc*/
# .cNqRrK{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}/*!sc*/
# data-styled.g243[id="sc-1iqzwcj-0"]{content:"cNqRrK,"}/*!sc*/
# .ezUEfJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g281[id="cgoejl-0"]{content:"ezUEfJ,"}/*!sc*/
# .iUBPac{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .iUBPac:first-child{margin-left:0;}/*!sc*/
# data-styled.g282[id="cgoejl-1"]{content:"iUBPac,"}/*!sc*/
# .fyTSuA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fyTSuA .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g283[id="cgoejl-2"]{content:"fyTSuA,"}/*!sc*/
# .dvEsae{padding-left:6px;}/*!sc*/
# data-styled.g284[id="cgoejl-3"]{content:"dvEsae,"}/*!sc*/
# .khMHQx{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g300[id="sc-2rneb0-0"]{content:"khMHQx,"}/*!sc*/
# .dJPUBs{position:relative;height:120px;padding:16px 0;width:100%;}/*!sc*/
# data-styled.g333[id="sc-1vxpibn-0"]{content:"dJPUBs,"}/*!sc*/
# .cUIXOd{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .cUIXOd img,.cUIXOd .ptn2cr-0{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .cUIXOd:hover img,.cUIXOd:hover .ptn2cr-0{fill:#ea5c5c;}/*!sc*/
# .czJYBa{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .czJYBa img,.czJYBa .ptn2cr-0{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .czJYBa:hover img,.czJYBa:hover .ptn2cr-0{fill:#3397cf;}/*!sc*/
# data-styled.g378[id="sc-17034tg-0"]{content:"cUIXOd,czJYBa,"}/*!sc*/
# .jPPEqC{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}/*!sc*/
# data-styled.g430[id="bvk29r-0"]{content:"jPPEqC,"}/*!sc*/
# .exUFVS{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g431[id="bvk29r-1"]{content:"exUFVS,"}/*!sc*/
# .bBJQEU{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g432[id="bvk29r-2"]{content:"bBJQEU,"}/*!sc*/
# .gFTsak{grid-column:mainRight / end;}/*!sc*/
# data-styled.g433[id="bvk29r-3"]{content:"gFTsak,"}/*!sc*/
# .eCLiVT{margin:0 12px;min-height:calc(100vh - 68px);min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g434[id="sc-10tqbnq-0"]{content:"eCLiVT,"}/*!sc*/
# .TuHNc{height:100%;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g435[id="sc-10tqbnq-1"]{content:"TuHNc,"}/*!sc*/
# .eLjDMI{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g453[id="uj732l-0"]{content:"eLjDMI,"}/*!sc*/
# .drhzCk{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# .hRmAez{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g454[id="uj732l-1"]{content:"drhzCk,hRmAez,"}/*!sc*/
# .kiokIt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .kiokIt:last-child{padding-right:0;}/*!sc*/
# .kiokIt .ptn2cr-0{width:20px;height:20px;margin-right:6px;}/*!sc*/
# data-styled.g455[id="uj732l-2"]{content:"kiokIt,"}/*!sc*/
# .dHzeJT{padding-right:8px;}/*!sc*/
# data-styled.g456[id="uj732l-3"]{content:"dHzeJT,"}/*!sc*/
# .iNZrQw{position:relative;z-index:1;}/*!sc*/
# data-styled.g457[id="uj732l-4"]{content:"iNZrQw,"}/*!sc*/
# .bpyTee{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g458[id="tgn9uw-0"]{content:"bpyTee,"}/*!sc*/
# .dOHhPe{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g459[id="tgn9uw-1"]{content:"dOHhPe,"}/*!sc*/
# .dHOiIN{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g460[id="tgn9uw-2"]{content:"dHOiIN,"}/*!sc*/
# .ebwnQU{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .ebwnQU::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g461[id="tgn9uw-3"]{content:"ebwnQU,"}/*!sc*/
# .ihDZjo{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g462[id="tgn9uw-4"]{content:"ihDZjo,"}/*!sc*/
# .skqzb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g480[id="j38qb8-0"]{content:"skqzb,"}/*!sc*/
# .hdngTq{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g481[id="j38qb8-1"]{content:"hdngTq,"}/*!sc*/
# .kgUVVH{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .kgUVVH >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g491[id="vnm9ni-0"]{content:"kgUVVH,"}/*!sc*/
# .gdnJeR{position:relative;}/*!sc*/
# .gdnJeR::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g494[id="m2vgdk-0"]{content:"gdnJeR,"}/*!sc*/
# .iCJYVe{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g529[id="sc-1bfxmuy-0"]{content:"iCJYVe,"}/*!sc*/
# .dxukUh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;position:relative;}/*!sc*/
# .dxukUh .ptn2cr-0{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g530[id="sc-1bfxmuy-1"]{content:"dxukUh,"}/*!sc*/
# .gJoEdt{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g542[id="d4ydwz-0"]{content:"gJoEdt,"}/*!sc*/
# .ippeWV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;white-space:nowrap;}/*!sc*/
# data-styled.g544[id="irx12-0"]{content:"ippeWV,"}/*!sc*/
# .gAqYKR{border-left:1px solid rgb(222,222,222);padding-right:10px;height:30px;}/*!sc*/
# data-styled.g545[id="irx12-1"]{content:"gAqYKR,"}/*!sc*/
# .hFULBQ{cursor:pointer;border:none;background:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0;height:100%;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;outline:none;}/*!sc*/
# .hFULBQ .ptn2cr-0{width:16px;height:16px;fill:#3397cf;}/*!sc*/
# data-styled.g546[id="irx12-2"]{content:"hFULBQ,"}/*!sc*/
# .dEYK{margin-left:2px;}/*!sc*/
# data-styled.g547[id="irx12-3"]{content:"dEYK,"}/*!sc*/
# .bCxACP{color:rgba(0,0,0,.35);padding:0 5px;}/*!sc*/
# data-styled.g548[id="irx12-4"]{content:"bCxACP,"}/*!sc*/
# .ktPclx{color:#3397cf;padding-left:2px;}/*!sc*/
# data-styled.g549[id="irx12-5"]{content:"ktPclx,"}/*!sc*/
# .hKpSvn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g550[id="sc-1nqrhll-0"]{content:"hKpSvn,"}/*!sc*/
# .kfqjCM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .kfqjCM > *{height:100%;width:100%;}/*!sc*/
# data-styled.g551[id="sc-1nqrhll-1"]{content:"kfqjCM,"}/*!sc*/
# .bbzyGK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# data-styled.g552[id="sc-1nqrhll-2"]{content:"bbzyGK,"}/*!sc*/
# .drIXZi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g553[id="sc-1iit2li-0"]{content:"drIXZi,"}/*!sc*/
# .bvTogh{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);}/*!sc*/
# data-styled.g554[id="sc-1iit2li-1"]{content:"bvTogh,"}/*!sc*/
# .EQHXJ{width:100%;z-index:1;}/*!sc*/
# data-styled.g560[id="sc-1iit2li-7"]{content:"EQHXJ,"}/*!sc*/
# .grCApu{padding:0 60px;}/*!sc*/
# data-styled.g562[id="sc-1thlyn3-0"]{content:"grCApu,"}/*!sc*/
# .kBRbec{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g564[id="sc-1kb03aj-0"]{content:"kBRbec,"}/*!sc*/
# .gvIkCW{width:100%;}/*!sc*/
# data-styled.g664[id="sc-131a6oy-0"]{content:"gvIkCW,"}/*!sc*/
# .eQpJeG{border-radius:12px;margin-top:8px;overflow:hidden;}/*!sc*/
# data-styled.g665[id="sc-1k1o5vl-0"]{content:"eQpJeG,"}/*!sc*/
# .gquyOJ{display:none;}/*!sc*/
# data-styled.g666[id="sc-1k1o5vl-1"]{content:"gquyOJ,"}/*!sc*/
# .gLJLIJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g667[id="sc-1k1o5vl-2"]{content:"gLJLIJ,"}/*!sc*/
# .hcJqep{margin:0 40px;border-bottom:1px solid rgb(233,233,233);}/*!sc*/
# data-styled.g669[id="sc-1k1o5vl-4"]{content:"hcJqep,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 slyeh"><div class="dz5d85-0 ejxNIo"><div class="dz5d85-1 QJLIQ"><a title="Dcard" class="dqjqtp-0 hoYSgn" href="/f"><img class="sc-139xjgq-0 gpsyNH" src="/_next/static/media/logo-b0a1bbe8c764051f49585fd8447205c5.svg" alt="Dcard"/></a><div class="bxef95-1 iSUXUZ"><div class="dj0ioy-0 dWIKEI"><form action=""><label class="oo2grd-0 fsbFQu"><div class="oo2grd-2 kpeJHB"><input type="search" placeholder="搜尋" aria-label="搜尋" class="oo2grd-4 kUcAWl dj0ioy-2 fxLlMR" value=""/></div></label><button type="submit" title="搜尋" disabled="" class="dj0ioy-3 DpBdT"><svg viewBox="0 0 28 28" class="ptn2cr-0 imJSLl dj0ioy-7 iGsnfv" focusable="false" width="20" height="20" style="fill:#fff" role="img" aria-hidden="true"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></button></form></div></div></div><div role="navigation" class="dz5d85-2 ekbLjl"><a class="jjui6k-0 bYrMBg sc-1ahzbiw-0 fIIvUe" role="button" href="/signup"><span class="jjui6k-1 bUWyLN">註冊 / 登入</span></a><div class="fdq12b-0 fNsDOn"><a class="jjui6k-0 hWGeTk" title="更多" role="button"><span class="jjui6k-1 bUWyLN"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 imJSLl"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path fill="none" d="M0 0h24v24H0z"></path></svg></span></a></div></div></div></div><div class="bvk29r-0 jPPEqC"><div class="bvk29r-1 exUFVS"><div class="sc-1bfxmuy-0 iCJYVe"><a href="/forum/all"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 imJSLl"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></div><div class="gthja3-1 loGeVD">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 imJSLl"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></div><div class="gthja3-1 loGeVD">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24" class="ptn2cr-0 imJSLl m2vgdk-0 gdnJeR" focusable="false" width="24" height="24" style="fill:#fff" role="img" aria-hidden="true"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path fill="none" d="M0 0h24v24H0z"></path></svg></div><div class="gthja3-1 loGeVD">好物研究室</div></div></a><div class="e7vhde-0 fuMuMk"><div class="simplebar- ...
# 「去你的吉娃娃勒」看到這些梗圖突然覺得我爸好像挺懂年輕人的啊！</span></a></h2><div class="uj732l-0 eLjDMI"><div class="tgn9uw-4 ihDZjo"><span>但是我今天在網路上看到這個真的覺得很好笑，放上來給大家看看🤣🤣，各種玩壞吉娃，補上壓軸，現在人生活太緊繃 壓力太大的都有，是時候放鬆看個梗圖笑一笑呦～照片出於fb 鈞鈞，有些照片沒有說明我直接連文字一</span></div></div><div class="uj732l-1 drhzCk"><div class="uj732l-2 kiokIt"><div class="cgoejl-0 ezUEfJ"><div class="cgoejl-2 fyTSuA"><img src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" title="愛心" style="z-index:3" class="cgoejl-1 iUBPac"/><img src="https://megapx-assets.dcard.tw/images/9a7cc9af-9f81-43ea-8d9b-968a6441ae51/orig.png" title="哈哈" style="z-index:2" class="cgoejl-1 iUBPac"/><img src="https://megapx-assets.dcard.tw/images/042b27f9-b507-473b-8f36-654aedcc37df/orig.png" title="森77" style="z-index:1" class="cgoejl-1 iUBPac"/></div><div class="cgoejl-3 dvEsae">1050</div></div></div><div class="uj732l-2 kiokIt"><span class="uj732l-3 dHzeJT">回應</span><span>56</span></div><div class="uj732l-4 iNZrQw"><div class="uj732l-2 kiokIt"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 imJSLl"><path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z"></path></svg><span>收藏</span></div></div></div><img class="sc-2rneb0-0 khMHQx tgn9uw-7 ksWRdc" src="https://imgur.dcard.tw/xZrlwpyb.jpg" width="84px" height="84px" alt="" loading="lazy" referrerPolicy="no-referrer"/></article></div><div data-index="30"><article class="tgn9uw-0 bpyTee" role="article" data-post-list-viewed-cell-no="31"><div class="tgn9uw-1 dOHhPe"><div class="euk31c-0 fSBNzX"><div class="euk31c-4 jeAXKr"><div class="yj50et-0 gXOxRC"><svg viewBox="0 0 40 40" focusable="false" width="16" height="16" class="ptn2cr-0 imJSLl"><title>女</title><path fill="#F48FB1" d="M40 20a20 20 0 11-40 0 20 20 0 0140 0"></path><path fill="#CB3A6B" d="M28.7 17.5a9.6 9.6 0 00-1.4-4.4l.9-.6S25.5 6 17.9 7.3c-5.5 1-7.7 5.4-7.4 9C10.8 19.8 8.3 31 8.3 31l6.7 1.7a4.6 4.6 0 00-.7 1.1v.1a4.2 4.2 0 00-.4.8l-1.3 3.8a20 20 0 0010.6 1.1L23 37c.4-2-.4-4-2-5 0-1.1 0-3 .5-3.1 3-.6 5.1-2.5 6.2-5.3.3.2.6.2 1 .2a1.5 1.5 0 00-.2-3c.1-1 .2-2.2 0-3.3z"></path></svg></div></div><div class="euk31c-1 iynvdK"><div class="euk31c-2 kFrzdN"><div class="euk31c-3 faNPqX">美食</div><div class="euk31c-3 faNPqX">中國科技大學</div></div></div></div></div><h2 class="tgn9uw-2 dHOiIN"><a class="tgn9uw-3 ebwnQU" href="/f/food/p/234699561"><span>萬華蟑螂紅豆湯</span></a></h2><div class="uj732l-0 eLjDMI"><div class="tgn9uw-4 ihDZjo"><span>上週心血來潮想喝紅豆湯，去萬華南機場外圍有一間 糖XXX，買一碗紅豆三寶，因為店家說剛好賣完要現煮，男友還特地等了半個小時，結果，噁爆，不喜歡蟑螂的朋友可以滑掉，這輩子不會再去買這一間了</span></div></div><div class="uj732l-1 drhzCk"><div class="uj732l-2 kiokIt"><div class="cgoejl-0 ezUEfJ"><div class="cgoejl-2 fyTSuA"><img src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" title="愛心" style="z-index:3" class="cgoejl-1 iUBPac"/><img src="https://megapx-assets.dcard.tw/images/2484e51a-2cdc-4f0e-a4ea-8d80b4589762/orig.png" title="驚訝" style="z-index:2" class="cgoejl-1 iUBPac"/><img src="https://megapx-assets.dcard.tw/images/042b27f9-b507-473b-8f36-654aedcc37df/orig.png" title="森77" style="z-index:1" class="cgoejl-1 iUBPac"/></div><div class="cgoejl-3 dvEsae">888</div></div></div><div class="uj732l-2 kiokIt"><span class="uj732l-3 dHzeJT">回應</span><span>114</span></div><div class="uj732l-4 iNZrQw"><div class="uj732l-2 kiokIt"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 imJSLl"><path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z"></path></svg><span>收藏</span></div></div></div><img class="sc-2rneb0-0 khMHQx tgn9uw-7 ksWRdc" src="https://imgur.dcard.tw/A1I43qPb.jpg" width="84px" height="84px" alt="" loading="lazy" referrerPolicy="no-referrer"/></article></div><div data-index="31"><article class="tgn9uw-0 bpyTee" role="article" data-post-list-viewed-cell-no="32"><div class="tgn9uw-1 dOHhPe"> ...

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')
print('因為 BeatifulSoup 可以解析HTML, XML等文件 ')
'''
Your Code Here
'''
soup = BeautifulSoup(response)
print(soup)
print(type(soup))
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="Dcard" name="application-name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="Dcard" property="al:ios:app_name"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><meta content="Dcard" property="al:android:app_name"/><link href="/_next/static/manifest.json" rel="manifest"/><link crossorigin="true" href="https://www.googletagmanager.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://certify.alexametrics.com" rel="dns-prefetch"/><link href="https://cloudfront-labs.amazonaws.com" rel="dns-prefetch"/><link href="https://bilanx.dcard.tw" rel="dns-prefetch"/><link href="https://imgur.dcard.tw" rel="dns-prefetch"/><link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/><link href="https://browser.sentry-cdn.com" rel="dns-prefetch"/><link href="https://gcs.dcard.tw" rel="dns-prefetch"/><link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><link href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/><link href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/><link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/><link href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/><meta charset="utf-8"/><meta content="廣受年輕人喜愛的 Dca ...
# window.dataLayer.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});</script><link as="script" href="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M" rel="preload"/><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M"></script><link as="style" href="/_next/static/css/dadeeca15b5600e0756f.css" rel="preload"/><link data-n-g="" href="/_next/static/css/dadeeca15b5600e0756f.css" rel="stylesheet"/><link as="style" href="/_next/static/css/64994a5464e7f7073c4f.css" rel="preload"/><link data-n-p="" href="/_next/static/css/64994a5464e7f7073c4f.css" rel="stylesheet"/><noscript data-n-css="true"></noscript><link as="script" href="/_next/static/chunks/c8f7fe3b0e41be846d5687592cf2018ff6e22687.7a44a07f74a8f93e1d70.js" rel="preload"/><link as="script" href="/_next/static/chunks/80e11efd05c4ccaf15f0d376a46097122b1c669e.41631194339cdb7cb4cf.js" rel="preload"/><link as="script" href="/_next/static/chunks/185.98ea6c8825d779f64821.js" rel="preload"/><link as="script" href="/_next/static/chunks/126.6eeaf79eed97dcc34683.js" rel="preload"/><link as="script" href="/_next/static/chunks/153.eada0432594218a8eaa3.js" rel="preload"/><link as="script" href="/_next/static/chunks/380d42e81165839365c4703ae67985f785a96bdc.9416a4c90343161b987e.js" rel="preload"/><link as="script" href="/_next/static/chunks/142.e6067637fed024c898fe.js" rel="preload"/><link as="script" href="/_next/static/chunks/46.60d28d6094641310dc89.js" rel="preload"/><link as="script" href="/_next/static/chunks/25ab9cf1609d20976391c6ff5814a65a5630e52a.77d5c15d8dfa64a8f20e.js" rel="preload"/><link as="script" href="/_next/static/chunks/18f082cfcb1201f92c925dfd848208caf2b75231.cb618eda4dc56580b406.js" rel="preload"/><link as="script" href="/_next/static/chunks/07ddc8feebba80388bd103699a5e8a2319231b85.37ff2c49c54eed9891c8.js" rel="preload"/><link as="script" href="/_next/static/chunks/128.c38afab1785c629fc8d0.js" rel="preload"/><link as="script" href="/_next/static/chunks/main-45a3d20d495d513f2cb2.js" rel="preload"/><link as="script" href="/_next/static/chunks/webpack-2d63783e44c767c0f7b4.js" rel="preload"/><link as="script" href="/_next/static/chunks/framework.c8a40be0a4bd8b0de1e4.js" rel="preload"/><link as="script" href="/_next/static/chunks/commons.58efa1e6e3086be54387.js" rel="preload"/><link as="script" href="/_next/static/chunks/af940c9434548c12cc7c4878ef443046ac565f64.bf9ff1b5108ceceee779.js" rel="preload"/><link as="script" href="/_next/static/chunks/5a16bf8b082149cf34290a37606666dcf70dc96b.a0850b7e6bbc5e7b56ba.js" rel="preload"/><link as="script" href="/_next/static/chunks/0739e2437b785912e27ffd919456f2c63c704c2e.a541b181cefa0c6140be.js" rel="preload"/><link as="script" href="/_next/static/chunks/3f90e53db2b3420ce9913a1147b75a89b251152f.25d5c941585adb2647dc.js" rel="preload"/><link as="script" href="/_next/static/chunks/074bda294865dd2edb60e1064d2ae271203d3d1b.6f5e6c05379fb6f45034.js" rel="preload"/><link as="script" href="/_next/static/chunks/61cc49119d2b5691d6272e0da4eb6fb517431513.e8fd6060c496301a5cad.js" rel="preload"/><link as="script" href="/_next/static/chunks/af2339f2d4829cb0126ee86819160423ab347ed1.4990ff223b58a54d569e.js" rel="preload"/><link as="script" href="/_next/static/chunks/0c80ce41c15f61748a3c63db6ee86255b82b52f9.4a0edc642462b9173dd3.js" rel="preload"/><link as="script" href="/_next/static/chunks/14852e28a2740a7c54d2d091e36b470df7a22399.be5c561c239c5182cada.js" rel="preload"/><link as="script" href="/_next/static/chunks/0f70e0b77fdcbda3872bda2ac8b6464287dd1707.631421c05703653075b8.js" rel="preload"/><link as="script" href="/_next/static/chunks/896ff3868846743fb9bcdf260cd6a0aacc60829b.2998d5ceb1ed3f39a3e9.js" rel="preload"/><link as="script" href="/_next/static/chunks/25ab9cf1609d20976391c6ff5814a65a5630e52a.77d5c15d8dfa64a8f20e.js" rel="preload"/><link as="script" href="/_next/static/chunks/fd52027c4ffa024220f1f2cf0877e464b7f9b6d4.0f51e94084e8c356570a.js" rel="preload"/><link as="script" href="/_next/static/chunks/18f082cfcb1201f ...
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .imJSLl{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="ptn2cr-0"]{content:"imJSLl,"}/*!sc*/
# .fsbFQu{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g3[id="oo2grd-0"]{content:"fsbFQu,"}/*!sc*/
# .kpeJHB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;}/*!sc*/
# data-styled.g5[id="oo2grd-2"]{content:"kpeJHB,"}/*!sc*/
# .kUcAWl{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-weight:400;font-size:16px;line-height:22px;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .kUcAWl::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .kUcAWl::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g7[id="oo2grd-4"]{content:"kUcAWl,"}/*!sc*/
# .dWIKEI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .dWIKEI form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g10[id="dj0ioy-0"]{content:"dWIKEI,"}/*!sc*/
# .fxLlMR{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .fxLlMR::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fxLlMR::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fxLlMR::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g12[id="dj0ioy-2"]{content:"fxLlMR,"}/*!sc*/
# .DpBdT{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g13[id="dj0ioy-3"]{content:"DpBdT,"}/*!sc*/
# .kTOvBu{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g18[id="pkcmwm-0"]{content:"kTOvBu,"}/*!sc*/
# .caQTgB{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .caQTgB:hover{color:rgba(0,0,0,1);}/*!sc*/
# .caQTgB::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .kCSJJy{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .kCSJJy:hover{color:rgba(0,0,0,1);}/*!sc*/
# .kCSJJy::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g19[id="pkcmwm-1"]{content:"caQTgB,kCSJJy,"}/*!sc*/
# .gXOxRC{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g30[id="yj50et-0"]{content:"gXOxRC,"}/*!sc*/
# .bTEUYx{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .hGaOnB{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g31[id="yj50et-1"]{content:"bTEUYx,hGaOnB,"}/*!sc*/
# .jfhwKA{display:block;border-radius:50%;object-fit:cover;}/*!sc*/
# data-styled.g32[id="yj50et-2"]{content:"jfhwKA,"}/*!sc*/
# .fSBNzX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g37[id="euk31c-0"]{content:"fSBNzX,"}/*!sc*/
# .iynvdK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g38[id="euk31c-1"]{content:"iynvdK,"}/*!sc*/
# .kFrzdN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g39[id="euk31c-2"]{content:"kFrzdN,"}/*!sc*/
# .faNPqX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .faNPqX:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g40[id="euk31c-3"]{content:"faNPqX,"}/*!sc*/
# .jeAXKr{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g41[id="euk31c-4"]{content:"jeAXKr,"}/*!sc*/
# .bYrMBg{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .hWGeTk{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g48[id="jjui6k-0"]{content:"bYrMBg,hWGeTk,"}/*!sc*/
# .bUWyLN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .bUWyLN .ptn2cr-0{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g49[id="jjui6k-1"]{content:"bUWyLN,"}/*!sc*/
# .fIIvUe{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g50[id="sc-1ahzbiw-0"]{content:"fIIvUe,"}/*!sc*/
# .gpsyNH{display:block;height:100%;}/*!sc*/
# data-styled.g51[id="sc-139xjgq-0"]{content:"gpsyNH,"}/*!sc*/
# .hoYSgn{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g52[id="dqjqtp-0"]{content:"hoYSgn,"}/*!sc*/
# .fNsDOn{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g69[id="fdq12b-0"]{content:"fNsDOn,"}/*!sc*/
# .gaXQMH .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g71[id="lhzs50-0"]{content:"gaXQMH,"}/*!sc*/
# .ejxNIo{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g72[id="dz5d85-0"]{content:"ejxNIo,"}/*!sc*/
# .QJLIQ{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g73[id="dz5d85-1"]{content:"QJLIQ,"}/*!sc*/
# .ekbLjl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g74[id="dz5d85-2"]{content:"ekbLjl,"}/*!sc*/
# .fuMuMk{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g78[id="e7vhde-0"]{content:"fuMuMk,"}/*!sc*/
# .cPhHIR{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .e7vhde-1,.cPhHIR:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .cPhHIR.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .cPhHIR.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g79[id="e7vhde-1"]{content:"cPhHIR,"}/*!sc*/
# .hCguNu{cursor:pointer;}/*!sc*/
# .hCguNu::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .e7vhde-2::before,.simplebar-mouse-entered .hCguNu::before,.simplebar-dragging .hCguNu::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .e7vhde-2::before,.simplebar-hover .hCguNu::before,.simplebar-mouse-entered .hCguNu::before,.simplebar-dragging .hCguNu::before{opacity:1;}/*!sc*/
# .hCguNu.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g80[id="e7vhde-2"]{content:"hCguNu,"}/*!sc*/
# .slyeh{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g82[id="bxef95-0"]{content:"slyeh,"}/*!sc*/
# .iSUXUZ{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g83[id="bxef95-1"]{content:"iSUXUZ,"}/*!sc*/
# .loGeVD{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g119[id="gthja3-1"]{content:"loGeVD,"}/*!sc*/
# .kbdjsU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .kbdjsU:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g126[id="sc-11gkikh-0"]{content:"kbdjsU,"}/*!sc*/
# .cvGPCw{position:relative;}/*!sc*/
# data-styled.g133[id="rlqnj2-0"]{content:"cvGPCw,"}/*!sc*/
# .jvPhGh{visibility:hidden;pointer-events:none;}/*!sc*/
# data-styled.g134[id="rlqnj2-1"]{content:"jvPhGh,"}/*!sc*/
# .eXNumK{position:absolute;left:0;top:0;right:0;bottom:0;}/*!sc*/
# data-styled.g135[id="rlqnj2-2"]{content:"eXNumK,"}/*!sc*/
# .cuaiVf{position:relative;}/*!sc*/
# data-styled.g184[id="nd4ft2-0"]{content:"cuaiVf,"}/*!sc*/
# .fUhntA{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .fUhntA vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g230[id="sc-1x2g0l4-0"]{content:"fUhntA,"}/*!sc*/
# .cNqRrK{display:block;cursor:-webkit-zoom-in;cursor:-moz-zoom-in;cursor:zoom-in;object-fit:cover;max-width:100%;max-height:60vh;}/*!sc*/
# data-styled.g243[id="sc-1iqzwcj-0"]{content:"cNqRrK,"}/*!sc*/
# .ezUEfJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g281[id="cgoejl-0"]{content:"ezUEfJ,"}/*!sc*/
# .iUBPac{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .iUBPac:first-child{margin-left:0;}/*!sc*/
# data-styled.g282[id="cgoejl-1"]{content:"iUBPac,"}/*!sc*/
# .fyTSuA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fyTSuA .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g283[id="cgoejl-2"]{content:"fyTSuA,"}/*!sc*/
# .dvEsae{padding-left:6px;}/*!sc*/
# data-styled.g284[id="cgoejl-3"]{content:"dvEsae,"}/*!sc*/
# .khMHQx{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g300[id="sc-2rneb0-0"]{content:"khMHQx,"}/*!sc*/
# .dJPUBs{position:relative;height:120px;padding:16px 0;width:100%;}/*!sc*/
# data-styled.g333[id="sc-1vxpibn-0"]{content:"dJPUBs,"}/*!sc*/
# .cUIXOd{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .cUIXOd img,.cUIXOd .ptn2cr-0{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .cUIXOd:hover img,.cUIXOd:hover .ptn2cr-0{fill:#ea5c5c;}/*!sc*/
# .czJYBa{padding:0 8px;border:none;background:none;height:100%;cursor:pointer;outline:none;}/*!sc*/
# .czJYBa img,.czJYBa .ptn2cr-0{display:block;width:24px;height:24px;fill:rgba(0,0,0,0.2);}/*!sc*/
# .czJYBa:hover img,.czJYBa:hover .ptn2cr-0{fill:#3397cf;}/*!sc*/
# data-styled.g378[id="sc-17034tg-0"]{content:"cUIXOd,czJYBa,"}/*!sc*/
# .jPPEqC{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}/*!sc*/
# data-styled.g430[id="bvk29r-0"]{content:"jPPEqC,"}/*!sc*/
# .exUFVS{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g431[id="bvk29r-1"]{content:"exUFVS,"}/*!sc*/
# .bBJQEU{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g432[id="bvk29r-2"]{content:"bBJQEU,"}/*!sc*/
# .gFTsak{grid-column:mainRight / end;}/*!sc*/
# data-styled.g433[id="bvk29r-3"]{content:"gFTsak,"}/*!sc*/
# .eCLiVT{margin:0 12px;min-height:calc(100vh - 68px);min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g434[id="sc-10tqbnq-0"]{content:"eCLiVT,"}/*!sc*/
# .TuHNc{height:100%;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g435[id="sc-10tqbnq-1"]{content:"TuHNc,"}/*!sc*/
# .eLjDMI{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g453[id="uj732l-0"]{content:"eLjDMI,"}/*!sc*/
# .drhzCk{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# .hRmAez{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g454[id="uj732l-1"]{content:"drhzCk,hRmAez,"}/*!sc*/
# .kiokIt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .kiokIt:last-child{padding-right:0;}/*!sc*/
# .kiokIt .ptn2cr-0{width:20px;height:20px;margin-right:6px;}/*!sc*/
# data-styled.g455[id="uj732l-2"]{content:"kiokIt,"}/*!sc*/
# .dHzeJT{padding-right:8px;}/*!sc*/
# data-styled.g456[id="uj732l-3"]{content:"dHzeJT,"}/*!sc*/
# .iNZrQw{position:relative;z-index:1;}/*!sc*/
# data-styled.g457[id="uj732l-4"]{content:"iNZrQw,"}/*!sc*/
# .bpyTee{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g458[id="tgn9uw-0"]{content:"bpyTee,"}/*!sc*/
# .dOHhPe{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g459[id="tgn9uw-1"]{content:"dOHhPe,"}/*!sc*/
# .dHOiIN{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g460[id="tgn9uw-2"]{content:"dHOiIN,"}/*!sc*/
# .ebwnQU{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .ebwnQU::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g461[id="tgn9uw-3"]{content:"ebwnQU,"}/*!sc*/
# .ihDZjo{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g462[id="tgn9uw-4"]{content:"ihDZjo,"}/*!sc*/
# .skqzb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g480[id="j38qb8-0"]{content:"skqzb,"}/*!sc*/
# .hdngTq{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g481[id="j38qb8-1"]{content:"hdngTq,"}/*!sc*/
# .kgUVVH{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .kgUVVH >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g491[id="vnm9ni-0"]{content:"kgUVVH,"}/*!sc*/
# .gdnJeR{position:relative;}/*!sc*/
# .gdnJeR::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g494[id="m2vgdk-0"]{content:"gdnJeR,"}/*!sc*/
# .iCJYVe{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g529[id="sc-1bfxmuy-0"]{content:"iCJYVe,"}/*!sc*/
# .dxukUh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;position:relative;}/*!sc*/
# .dxukUh .ptn2cr-0{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g530[id="sc-1bfxmuy-1"]{content:"dxukUh,"}/*!sc*/
# .gJoEdt{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g542[id="d4ydwz-0"]{content:"gJoEdt,"}/*!sc*/
# .ippeWV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:stretch;-ms-flex-item-align:stretch;align-self:stretch;white-space:nowrap;}/*!sc*/
# data-styled.g544[id="irx12-0"]{content:"ippeWV,"}/*!sc*/
# .gAqYKR{border-left:1px solid rgb(222,222,222);padding-right:10px;height:30px;}/*!sc*/
# data-styled.g545[id="irx12-1"]{content:"gAqYKR,"}/*!sc*/
# .hFULBQ{cursor:pointer;border:none;background:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0;height:100%;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;outline:none;}/*!sc*/
# .hFULBQ .ptn2cr-0{width:16px;height:16px;fill:#3397cf;}/*!sc*/
# data-styled.g546[id="irx12-2"]{content:"hFULBQ,"}/*!sc*/
# .dEYK{margin-left:2px;}/*!sc*/
# data-styled.g547[id="irx12-3"]{content:"dEYK,"}/*!sc*/
# .bCxACP{color:rgba(0,0,0,.35);padding:0 5px;}/*!sc*/
# data-styled.g548[id="irx12-4"]{content:"bCxACP,"}/*!sc*/
# .ktPclx{color:#3397cf;padding-left:2px;}/*!sc*/
# data-styled.g549[id="irx12-5"]{content:"ktPclx,"}/*!sc*/
# .hKpSvn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g550[id="sc-1nqrhll-0"]{content:"hKpSvn,"}/*!sc*/
# .kfqjCM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .kfqjCM > *{height:100%;width:100%;}/*!sc*/
# data-styled.g551[id="sc-1nqrhll-1"]{content:"kfqjCM,"}/*!sc*/
# .bbzyGK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# data-styled.g552[id="sc-1nqrhll-2"]{content:"bbzyGK,"}/*!sc*/
# .drIXZi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g553[id="sc-1iit2li-0"]{content:"drIXZi,"}/*!sc*/
# .bvTogh{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);}/*!sc*/
# data-styled.g554[id="sc-1iit2li-1"]{content:"bvTogh,"}/*!sc*/
# .EQHXJ{width:100%;z-index:1;}/*!sc*/
# data-styled.g560[id="sc-1iit2li-7"]{content:"EQHXJ,"}/*!sc*/
# .grCApu{padding:0 60px;}/*!sc*/
# data-styled.g562[id="sc-1thlyn3-0"]{content:"grCApu,"}/*!sc*/
# .kBRbec{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g564[id="sc-1kb03aj-0"]{content:"kBRbec,"}/*!sc*/
# .gvIkCW{width:100%;}/*!sc*/
# data-styled.g664[id="sc-131a6oy-0"]{content:"gvIkCW,"}/*!sc*/
# .eQpJeG{border-radius:12px;margin-top:8px;overflow:hidden;}/*!sc*/
# data-styled.g665[id="sc-1k1o5vl-0"]{content:"eQpJeG,"}/*!sc*/
# .gquyOJ{display:none;}/*!sc*/
# data-styled.g666[id="sc-1k1o5vl-1"]{content:"gquyOJ,"}/*!sc*/
# .gLJLIJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g667[id="sc-1k1o5vl-2"]{content:"gLJLIJ,"}/*!sc*/
# .hcJqep{margin:0 40px;border-bottom:1px solid rgb(233,233,233);}/*!sc*/
# data-styled.g669[id="sc-1k1o5vl-4"]{content:"hcJqep,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 slyeh"><div class="dz5d85-0 ejxNIo"><div class="dz5d85-1 QJLIQ"><a class="dqjqtp-0 hoYSgn" href="/f" title="Dcard"><img alt="Dcard" class="sc-139xjgq-0 gpsyNH" src="/_next/static/media/logo-b0a1bbe8c764051f49585fd8447205c5.svg"/></a><div class="bxef95-1 iSUXUZ"><div class="dj0ioy-0 dWIKEI"><form action=""><label class="oo2grd-0 fsbFQu"><div class="oo2grd-2 kpeJHB"><input aria-label="搜尋" class="oo2grd-4 kUcAWl dj0ioy-2 fxLlMR" placeholder="搜尋" type="search" value=""/></div></label><button class="dj0ioy-3 DpBdT" disabled="" title="搜尋" type="submit"><svg aria-hidden="true" class="ptn2cr-0 imJSLl dj0ioy-7 iGsnfv" focusable="false" height="20" role="img" style="fill:#fff" viewbox="0 0 28 28" width="20"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></button></form></div></div></div><div class="dz5d85-2 ekbLjl" role="navigation"><a class="jjui6k-0 bYrMBg sc-1ahzbiw-0 fIIvUe" href="/signup" role="button"><span class="jjui6k-1 bUWyLN">註冊 / 登入</span></a><div class="fdq12b-0 fNsDOn"><a class="jjui6k-0 hWGeTk" role="button" title="更多"><span class="jjui6k-1 bUWyLN"><svg aria-hidden="true" class="ptn2cr-0 imJSLl" focusable="false" role="img" viewbox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></a></div></div></div></div><div class="bvk29r-0 jPPEqC"><div class="bvk29r-1 exUFVS"><div class="sc-1bfxmuy-0 iCJYVe"><a href="/forum/all"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg aria-hidden="true" class="ptn2cr-0 imJSLl" focusable="false" role="img" viewbox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></div><div class="gthja3-1 loGeVD">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg aria-hidden="true" class="ptn2cr-0 imJSLl" focusable="false" role="img" viewbox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></div><div class="gthja3-1 loGeVD">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 kbdjsU"><div class="sc-1bfxmuy-1 dxukUh"><svg aria-hidden="true" class="ptn2cr-0 imJSLl m2vgdk-0 gdnJeR" focusable="false" height="24" role="img" style="fill:#fff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></div><div class="gthja3-1 loGeVD">好物研究室</div></div></a><div class="e7vhde-0 fuMuMk"><div class="simplebar- ...
# 「去你的吉娃娃勒」看到這些梗圖突然覺得我爸好像挺懂年輕人的啊！</span></a></h2><div class="uj732l-0 eLjDMI"><div class="tgn9uw-4 ihDZjo"><span>但是我今天在網路上看到這個真的覺得很好笑，放上來給大家看看🤣🤣，各種玩壞吉娃，補上壓軸，現在人生活太緊繃 壓力太大的都有，是時候放鬆看個梗圖笑一笑呦～照片出於fb 鈞鈞，有些照片沒有說明我直接連文字一</span></div></div><div class="uj732l-1 drhzCk"><div class="uj732l-2 kiokIt"><div class="cgoejl-0 ezUEfJ"><div class="cgoejl-2 fyTSuA"><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:3" title="愛心"/><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/9a7cc9af-9f81-43ea-8d9b-968a6441ae51/orig.png" style="z-index:2" title="哈哈"/><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/042b27f9-b507-473b-8f36-654aedcc37df/orig.png" style="z-index:1" title="森77"/></div><div class="cgoejl-3 dvEsae">1050</div></div></div><div class="uj732l-2 kiokIt"><span class="uj732l-3 dHzeJT">回應</span><span>56</span></div><div class="uj732l-4 iNZrQw"><div class="uj732l-2 kiokIt"><svg aria-hidden="true" class="ptn2cr-0 imJSLl" focusable="false" role="img" viewbox="0 0 24 24"><path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z"></path></svg><span>收藏</span></div></div></div><img alt="" class="sc-2rneb0-0 khMHQx tgn9uw-7 ksWRdc" height="84px" loading="lazy" referrerpolicy="no-referrer" src="https://imgur.dcard.tw/xZrlwpyb.jpg" width="84px"/></article></div><div data-index="30"><article class="tgn9uw-0 bpyTee" data-post-list-viewed-cell-no="31" role="article"><div class="tgn9uw-1 dOHhPe"><div class="euk31c-0 fSBNzX"><div class="euk31c-4 jeAXKr"><div class="yj50et-0 gXOxRC"><svg class="ptn2cr-0 imJSLl" focusable="false" height="16" viewbox="0 0 40 40" width="16"><title>女</title><path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#F48FB1"></path><path d="M28.7 17.5a9.6 9.6 0 00-1.4-4.4l.9-.6S25.5 6 17.9 7.3c-5.5 1-7.7 5.4-7.4 9C10.8 19.8 8.3 31 8.3 31l6.7 1.7a4.6 4.6 0 00-.7 1.1v.1a4.2 4.2 0 00-.4.8l-1.3 3.8a20 20 0 0010.6 1.1L23 37c.4-2-.4-4-2-5 0-1.1 0-3 .5-3.1 3-.6 5.1-2.5 6.2-5.3.3.2.6.2 1 .2a1.5 1.5 0 00-.2-3c.1-1 .2-2.2 0-3.3z" fill="#CB3A6B"></path></svg></div></div><div class="euk31c-1 iynvdK"><div class="euk31c-2 kFrzdN"><div class="euk31c-3 faNPqX">美食</div><div class="euk31c-3 faNPqX">中國科技大學</div></div></div></div></div><h2 class="tgn9uw-2 dHOiIN"><a class="tgn9uw-3 ebwnQU" href="/f/food/p/234699561"><span>萬華蟑螂紅豆湯</span></a></h2><div class="uj732l-0 eLjDMI"><div class="tgn9uw-4 ihDZjo"><span>上週心血來潮想喝紅豆湯，去萬華南機場外圍有一間 糖XXX，買一碗紅豆三寶，因為店家說剛好賣完要現煮，男友還特地等了半個小時，結果，噁爆，不喜歡蟑螂的朋友可以滑掉，這輩子不會再去買這一間了</span></div></div><div class="uj732l-1 drhzCk"><div class="uj732l-2 kiokIt"><div class="cgoejl-0 ezUEfJ"><div class="cgoejl-2 fyTSuA"><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/52057289-337a-4f2f-88c0-cb8a77ee422a/orig.png" style="z-index:3" title="愛心"/><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/2484e51a-2cdc-4f0e-a4ea-8d80b4589762/orig.png" style="z-index:2" title="驚訝"/><img class="cgoejl-1 iUBPac" src="https://megapx-assets.dcard.tw/images/042b27f9-b507-473b-8f36-654aedcc37df/orig.png" style="z-index:1" title="森77"/></div><div class="cgoejl-3 dvEsae">888</div></div></div><div class="uj732l-2 kiokIt"><span class="uj732l-3 dHzeJT">回應</span><span>114</span></div><div class="uj732l-4 iNZrQw"><div class="uj732l-2 kiokIt"><svg aria-hidden="true" class="ptn2cr-0 imJSLl" focusable="false" role="img" viewbox="0 0 24 24"><path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z"></path></svg><span>收藏</span></div></div></div><img alt="" class="sc-2rneb0-0 khMHQx tgn9uw-7 ksWRdc" height="84px" loading="lazy" referrerpolicy="no-referrer" src="https://imgur.dcard.tw/A1I43qPb.jpg" width="84px"/></article></div><div data-index="31"><article class="tgn9uw-0 bpyTee" data-post-list-viewed-cell-no="32" role="article"><div class="tgn9uw-1 dOHhPe"> ...
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

'''
Your Code Here
'''
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get(url,headers=headers)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="有问题，上知乎。知乎，可信赖的问答社区，以让每个人高效获得可信赖的解答为使命。知乎凭借认真、专业和友善的社区氛围，结构化、易获得的
