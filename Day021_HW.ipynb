# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
'''
Your Code
'''
#打開瀏覽器
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")


# 每個兩秒鐘自動往下滑
import time
for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")

    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)


# 關閉瀏覽器
browser.quit();

# %%
print(soup)

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
'''
Your Code
'''

from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')
browser.get("https://www.ettoday.net/news/news-list.htm")

import time
import datetime

current_time=datetime.datetime.now()
current_timestamp = datetime.datetime.timestamp(current_time)

# 每個兩秒鐘自動往下滑

import time

for i in range(10):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, 10000);")

# 取得資料，丟到 BeautifulSoup 解析

html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")
in2hour_time_stamp = int(datetime.datetime.timestamp(current_time-datetime.timedelta(hours=2)))
for d in soup.find(class_="part_list_2").find_all('h3'):
    time_str = d.find(class_="date").text
    time_stamp = int(time.mktime(datetime.datetime.strptime(time_str, "%Y/%m/%d %H:%M").timetuple()))
    if(time_stamp >= in2hour_time_stamp):
        print(time_str, d.find_all('a')[-1].text)
        

# 關閉瀏覽器
browser.quit();

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
'''
Your Code
'''
#打開瀏覽器
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome(executable_path='chromedriver')

browser.get("https://www.ettoday.net/news/news-list.htm")

import time
import datetime

current_time=datetime.datetime.now()
current_timestamp = datetime.datetime.timestamp(current_time)
browser = webdriver.Chrome(executable_path='chromedriver')
current_date_str=(current_time - datetime.timedelta(days=3)).strftime("%Y-%m-%d")
browser.get("https://www.ettoday.net/news/news-list-"+current_date_str+"-0.htm")
fromTime_str=current_date_str+" 15:00"
toTime_str=current_date_str+" 17:00"
fromTimestamp = int(time.mktime(datetime.datetime.strptime(fromTime_str, "%Y-%m-%d %H:%M").timetuple()))
toTimestamp = int(time.mktime(datetime.datetime.strptime(toTime_str, "%Y-%m-%d %H:%M").timetuple()))
# 每個兩秒鐘自動往下滑

for i in range(50):
    time.sleep(0.5)
    browser.execute_script("window.scrollTo(0, 50000);")

# 取得資料，丟到 BeautifulSoup 解析

html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")

for d in soup.find(class_="part_list_2").find_all('h3'):
    time_str = d.find(class_="date").text
    time_stamp = int(time.mktime(datetime.datetime.strptime(time_str, "%Y/%m/%d %H:%M").timetuple()))
    if(time_stamp >= fromTimestamp and time_stamp <= toTimestamp):
        print(time_str, d.find_all('a')[-1].text)

# 關閉瀏覽器
browser.quit();
# Out:
# 2020/10/31 17:00 新竹人快來放空！隱身山林的療癒咖啡館　必點超濃郁茄汁燉飯
# 2020/10/31 16:57 台灣大賽／棄投從打總冠軍賽　杜家明：全新身分
# 2020/10/31 16:55 大學園藝系搭萬聖節風潮　上課教雕南瓜訣竅...學習加工景觀規劃
# 2020/10/31 16:54 又放閃！「品學聯合服務處」一日限定開張　網：原來是情人節
# 2020/10/31 16:53 台灣大賽／林岳平挑染變身獅子王　笑稱帶了螺帽鎖羅傑斯
# 2020/10/31 16:53 彩虹城市管樂團同志大遊行演奏經典7曲目　連6年傳遞各種愛
# 2020/10/31 16:50 「沒有期待，就不怕受傷害」　面對感情先做好最「壞」打算
# 2020/10/31 16:49 不只爬108層刀梯！台灣首屆玄門文化研討.....道士與學界對話
# 2020/10/31 16:47 動物演戲有多難？　狗4小時想睡、雞拍1個月就長大
# 2020/10/31 16:47 誆西非官二代移民來台急需現金　魔術手法「洗美金」詐475萬
# 2020/10/31 16:44 近8成民眾「願意接受」投票結果　美國選後亂象被誇大
# 2020/10/31 16:43 台灣大賽／林書逸抱著必死決心　晚上聽球迷聲音特打
# 2020/10/31 16:42 母子腐屍「半裸坐沙發」眼眶成空洞　屋內擺設超毛…字條：別進來
# 2020/10/31 16:41 以為是痔瘡發作...微創解決「複雜性肛門廔管」　3天即正常生活
# 2020/10/31 16:40 高舉彩虹旗挺同志遊行　祁家威：下一步盼「跨國同婚合法化」
# 2020/10/31 16:38 按摩妹「超誘惑低胸短裙」　一旁老婆眼神變了！逼出神猛求生慾
# 2020/10/31 16:36 一券多用好彈性　台北旅展「聯合住宿券」超搶手
# 2020/10/31 16:36 嘉義極光歐若拉登國際旅展　第一天爆量銷售
# 2020/10/31 16:33 台灣大賽／「我也是第一次嘛」　林岳平真除要大家找亮點
# 2020/10/31 16:33 金剛猩猩Tayari產子影片曝！　緊擁懷「整天抱著寶寶」眼神超有愛
# 2020/10/31 16:33 黃偉哲向家屬道歉...未遂案警為何沒給報案三聯單：調查公布真相
# ...
